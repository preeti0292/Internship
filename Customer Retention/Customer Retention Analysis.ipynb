# %%
#Import Necessary Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Dataset

# %%
#Read dataset
data = pd.read_excel(r"D:\Fliprobo\customer_retention_dataset.xlsx")
data.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
#Checking number of rows and columns of the dataset
data.shape
# Out:
# (269, 71)

# %% [markdown]
# * There are 269 rows and 71 columns present in the dataset.

# %%
#Checking unique details of the dataset
data.nunique()
# Out:
# 1Gender of respondent                                                    2
# 2 How old are you?                                                       5
# 3 Which city do you shop online from?                                   11
# 4 What is the Pin Code of where you shop online from?                   39
# 5 Since How Long You are Shopping Online ?                               5
#                                                                         ..
# Longer delivery period                                                   6
# Change in website/Application design                                     7
# Frequent disruption when moving from one page to another                 8
# Website is as efficient as before                                        8
# Which of the Indian online retailer would you recommend to a friend?     8
# Length: 71, dtype: int64

# %%
#Checking types of the dataset
data.dtypes
# Out:
# 1Gender of respondent                                                   object
# 2 How old are you?                                                      object
# 3 Which city do you shop online from?                                   object
# 4 What is the Pin Code of where you shop online from?                    int64
# 5 Since How Long You are Shopping Online ?                              object
#                                                                          ...
# Longer delivery period                                                  object
# Change in website/Application design                                    object
# Frequent disruption when moving from one page to another                object
# Website is as efficient as before                                       object
# Which of the Indian online retailer would you recommend to a friend?    object
# Length: 71, dtype: object

# %%
#Checking number of object column present in this dataset
data.dtypes[data.dtypes == 'object'].count()
# Out:
# 70

# %% [markdown]
# * 70 object columns and 1 numerical columns present in the dataset.

# %%
#Will separate categorical and numerical columns
categorical_cols = []
numerical_cols = []
for i in data.dtypes.index:
    if data.dtypes[i] == 'object':
        categorical_cols.append(i)
    else:
        numerical_cols.append(i)

# %%
categorical_cols
# Out:
# ['1Gender of respondent',
#  '2 How old are you? ',
#  '3 Which city do you shop online from?',
#  '5 Since How Long You are Shopping Online ?',
#  '6 How many times you have made an online purchase in the past 1 year?',
#  '7 How do you access the internet while shopping on-line?',
#  '8 Which device do you use to access the online shopping?',
#  '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#  '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#  '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#  '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#  '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
# ...

# %%
numerical_cols
# Out:
# ['4 What is the Pin Code of where you shop online from?']

# %%
#Checking Null values
data.isnull().sum()
# Out:
# 1Gender of respondent                                                   0
# 2 How old are you?                                                      0
# 3 Which city do you shop online from?                                   0
# 4 What is the Pin Code of where you shop online from?                   0
# 5 Since How Long You are Shopping Online ?                              0
#                                                                        ..
# Longer delivery period                                                  0
# Change in website/Application design                                    0
# Frequent disruption when moving from one page to another                0
# Website is as efficient as before                                       0
# Which of the Indian online retailer would you recommend to a friend?    0
# Length: 71, dtype: int64

# %%
#Visualizing null values
sns.heatmap(data.isnull())
plt.show()

# %% [markdown]
# * No Null values present in the dataset.

# %% [markdown]
# # Exploratory Data Analysis

# %%
#Checking unique values of the dataset
data['1Gender of respondent'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#Checking counts of gender 
data['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
#Visualizing gender feature
labels = ['Female','Male']
fig, ax = plt.subplots(dpi = 100)
cl = ['blue','green']
plt.legend
exp = [0.0, 0.2]
plt.pie(data['1Gender of respondent'].value_counts(),labels = labels,explode = exp,radius =1, autopct = '%1.2f%%', shadow = True, colors = cl)
plt.show()

# %% [markdown]
# * From above plot I can observe that the count of Female seems to be higher in respondant.

# %%
#Checking unique values of Age
pd.DataFrame(data['2 How old are you? '].unique())
# Out:
#                     0
# 0         31-40 years
# 1         21-30 years
# 2         41-50 yaers
# 3  Less than 20 years
# 4  51 years and above

# %%
#Checking counts of each Age brackets
data['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
#Visualizing Age column
plt.figure(figsize = (10,5))
sns.countplot(data['2 How old are you? '], palette = "viridis")
plt.title('Online Shopping done by different age groups of the society')
plt.show()

# %% [markdown]
# * We can observe that age group between 31-40 years are the highest users of online shopping platforms followed by 21-30 years and 41-50 years of age groups.

# %%
#Checking unique values of City
data['3 Which city do you shop online from?'].unique()
# Out:
# array(['Delhi', 'Greater Noida', 'Karnal ', 'Bangalore ', 'Noida',
#        'Solan', 'Moradabad', 'Gurgaon ', 'Merrut', 'Ghaziabad',
#        'Bulandshahr'], dtype=object)

# %%
#Checking value counts of city
data['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
#Visualizing City
plt.subplots(figsize = (15,6))
sns.countplot(data['3 Which city do you shop online from?'], palette = 'Set2')
plt.show()

# %% [markdown]
# * Delhi has the highest number of customers who shop online and Bulandshahir has the least.

# %%
#Visualizing pincode
plt.subplots(figsize = (15,6))
sns.countplot(data['4 What is the Pin Code of where you shop online from?'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * 201308 is the area pincode from where online shopping have been done more.

# %%
#Visualizing how long you are shopping online
plt.subplots(figsize = (15,6))
sns.countplot(data['5 Since How Long You are Shopping Online ?'], palette = 'hot')
plt.show()

# %% [markdown]
# * The above graph shows that people shopping sincw more than 4 years seems to be higher in count from the given dataset.

# %%
#Visualizing how do you access the internet while shopping online
plt.subplots(figsize = (8,6))
sns.countplot(data['7 How do you access the internet while shopping on-line?'], palette = 'coolwarm')
plt.show()

# %% [markdown]
# * Most of the customers use Mobile internet while doing online shopping.

# %%
#Visualizing which device do you use to access the online shopping
plt.subplots(figsize = (10,6))
sns.countplot(data['8 Which device do you use to access the online shopping?'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * We can see that "SmartPhone" plays vital role in online purchase.
# * The number of count is higher with people using "Smartphone" for online purchase.

# %% [markdown]
# # Removing white space infront and back of all columns

# %%
#Removing space from all columns
data.columns = data.columns.str.rstrip()
data.columns = data.columns.str.lstrip()

# %%
#Visualizing What is the screen size of your mobile device
plt.subplots(figsize = (8,6))
sns.countplot(data['9 What is the screen size of your mobile device?'], palette = 'Paired')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * The count of devices is higher with the screen size greater than 5 inches or may be less that 4.7 inches (i.e) "Others" Catogory class.

# %%
#Visualizing What is the operating system (OS) of your device
plt.subplots(figsize = (8,6))
sns.countplot(data['10 What is the operating system (OS) of your device?'], palette = 'rocket')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * 'Windows Mobile' OS has the higher counts when compared to IOS,Andrioid for online shopping.

# %%
#Visualizing What browser do you run on your device to access the website?
plt.subplots(figsize = (8,6))
sns.countplot(data['11 What browser do you run on your device to access the website?'], palette = 'mako')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * The graph shows that the count of people using "Google Chrome" for online shpping is higher than other browsers.

# %%
#Visualizing 12 Which channel did you follow to arrive at your favorite online store for the first time?
plt.subplots(figsize = (8,6))
sns.countplot(data['12 Which channel did you follow to arrive at your favorite online store for the first time?'], palette = 'Set2')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * "Search Engine" has the higher counts to arrive at the favorite online store for 1st time.

# %%
#Visualizing 13 After first visit, how do you reach the online retail store?
plt.subplots(figsize = (8,6))
sns.countplot(data['13 After first visit, how do you reach the online retail store?'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Observation tells that after first visit for online store was mostly through "Search Engine",and  "Via application".

# %%
#Visualizing 14 How much time do you explore the e- retail store before making a purchase decision
plt.subplots(figsize = (8,6))
sns.countplot(data['14 How much time do you explore the e- retail store before making a purchase decision?'], palette = 'flare')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Observation shows that the time taken to explore e-retail store for purchase decision is more than 15 mins. So only few purchases are done less than 10 mins.

# %%
#Visualizing 15 What is your preferred payment Option?
plt.subplots(figsize = (8,6))
sns.countplot(data['15 What is your preferred payment Option?'], palette = 'crest')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Observation shows that most of the Payment options are done by "Credit/Debit cards" as the count is higher. Next is by "Cash on delivery".

# %%
#Visualizing 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart
plt.subplots(figsize = (8,6))
sns.countplot(data['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Observation shows that the count of "Sometimes"  is higher and hence the tells that people selecting and leaving without making payment is  only sometimes.

# %%
#Visualizing 17 Why did you abandon the “Bag”, “Shopping Cart”?
plt.subplots(figsize = (8,6))
sns.countplot(data['17 Why did you abandon the “Bag”, “Shopping Cart”?'], palette = 'rocket_r')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * The Graph shows that most of the time the abandon was due to higher counts of 'Better alternative offer'.

# %%
#Visualizing The content on the website must be easy to read and understand
plt.subplots(figsize = (8,6))
sns.countplot(data['18 The content on the website must be easy to read and understand'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * The content on the website must be easy to read and understand has the higher count on "Strongly agree"

# %%
#Visualizing Information on similar product to the one highlighted  is important for product comparison
plt.subplots(figsize = (8,6))
sns.countplot(data['19 Information on similar product to the one highlighted  is important for product comparison'], palette = 'cubehelix')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * "Information on similar product to the one highlighted  is important for product comparison" has higher counts on class "Strongly agree".

# %%
#Visualizing Complete information on listed seller and product being offered is important for purchase decision
plt.subplots(figsize = (8,6))
sns.countplot(data['20 Complete information on listed seller and product being offered is important for purchase decision.'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Complete information on listed seller and product being offered is important for purchase decision as the count is higher for 2 classes like "Strongly agree","Agree".

# %%
#Visualizing All relevant information on listed products must be stated clearly
plt.subplots(figsize = (8,6))
sns.countplot(data['21 All relevant information on listed products must be stated clearly'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * All relevant information on listed products must be stated clearly has the higher counts for "Agree" class.

# %%
#Visualizing Ease of navigation in website
plt.subplots(figsize = (8,6))
sns.countplot(data['22 Ease of navigation in website'], palette = 'light:b')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Ease of navigation in website required has higher count on the "Strongly agree" class.

# %%
#Visualizing Loading and processing speed 
plt.subplots(figsize = (8,6))
sns.countplot(data['23 Loading and processing speed'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Loading and processing speed has higher counts on class "Strongly agree" and next is "agree".

# %%
#Visualizing User friendly Interface of the website
plt.subplots(figsize = (8,6))
sns.countplot(data['24 User friendly Interface of the website'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * User friendly Interface of the website is highly required by stating the option "Strongly agree" with maximum counts.

# %%
#Visualizing From the following, tick any (or all) of the online retailers you have shopped from
plt.subplots(figsize = (8,6))
sns.countplot(data['From the following, tick any (or all) of the online retailers you have shopped from;'], palette = 'hsv')
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * Observation shows that many of them do shopping from almost all retailers with the class mentioning (having higher counts above 80) "Amazon.in, Flipcart.com, Paytm.com, Snapdeal.com"

# %%
#Visualizing city and age with gender
plt.figure(figsize = (15,7))
sns.countplot(data['3 Which city do you shop online from?'], hue = data['1Gender of respondent'], palette = 'dark:salmon_r')
plt.title('Shopping  comparison City vs Gender');

# %% [markdown]
# * In Delhi, noida, moradabad, bulandsahar online shopping done by male is far more greater than female but in  Greaternoida, karnal, Banglore, gurgaon, merrut , Ghaziabd female outnumbered male in shopping.

# %%
#Visualizing City vs Age
plt.figure(figsize = (20,7))
sns.countplot(data['3 Which city do you shop online from?'], hue = data['2 How old are you?'], palette = 'hot')
plt.title('Shopping  comparison City vs Age');

# %% [markdown]
# * In Delhi shopping done by 41 to 50 years age group are in abundant whearas in greater noida and noida 31 to 40 year age group lead the chart in shopping

# %%
#Visualizing frequency of online purchanse and Age
plt.figure(figsize=(20,7),facecolor = 'white')
sns.countplot(data['6 How many times you have made an online purchase in the past 1 year?'], hue = data['2 How old are you?'], palette = 'YlOrBr')
plt.show()

# %%
#Visualizing OS vs device uses while doing online shopping
plt.figure(figsize = (13,6))
sns.countplot(data['10 What is the operating system (OS) of your device?'],hue = data['8 Which device do you use to access the online shopping?'], palette = 'Blues')
plt.legend(bbox_to_anchor = (1.05, 1))
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.countplot(data['11 What browser do you run on your device to access the website?'], hue = data['8 Which device do you use to access the online shopping?'], palette = 'vlag')
plt.legend(bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# * Overall we can say that Google chrome is widely used in all devices.

# %%
#Analyzing the Relationship brtweeen customers retention VS Risks inherited
plt.figure(figsize = (40,70))
plotnum = 1
y = data[['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?','17 Why did you abandon the “Bag”, “Shopping Cart”?','Longer delivery period','Frequent disruption when moving from one page to another','Longer page loading time (promotion, sales period)','Perceived Trustworthiness','Security of customer financial information','Privacy of customers’ information','38 User satisfaction cannot exist without trust','26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time','Longer time to get logged in (promotion, sales period)', 'Longer time in displaying graphics and photos (promotion, sales period)','Late declaration of price (promotion, sales period)',]]
X = data['Which of the Indian online retailer would you recommend to a friend?']
for col in y:
    if plotnum <= 13:
        plt.subplot(13,1, plotnum)
        sns.countplot(X, hue = y[col])
        plt.xlabel('Which of the Indian online retailer would you recommend to a friend?',fontsize = 20)
        plt.ylabel('Count',fontsize = 20)
    plotnum += 1
plt.tight_layout()
